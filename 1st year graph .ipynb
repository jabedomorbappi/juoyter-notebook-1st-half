# %%
import matplotlib.pyplot as plt

import numpy as np

# create 1000 equally spaced points between -10 and 10
x = np.linspace(-12, 10, 1000)

# calculate the y value for each element of the x vector
y = x**2 + 2*x + 2  
plt.plot(x,y)

# %%
x = np.arange(-100,100,1)

y = x**2

plt.plot(x,y)

plt.show()

# %%
x=np.linspace(-100,100)
a=1
b=2
c=36
y=a*x**2+b*x+c
plt.plot(x,y)
plt.grid()

# %%
#Hyperbola
x=np.linspace(-100,100)
a=1
b=2
y=np.sqrt((x/a)**2-a*b**2)
plt.plot(x,y)
plt.grid()

# %%
#sin graph
time=np.arange(0,20,0.1)
amplitude=np.sin(time)
plt.plot(time,amplitude)
plt.grid()
plt.axis([0,10,-1,1])
# Out:
# [0, 10, -1, 1]

# %%
#cos graph

time=np.arange(0,20,0.1)
amplitude=np.cos(time)
plt.plot(time,amplitude)
plt.grid()

# %%
time=np.arange(-1,2,0.5)
amplitude=np.tan(time)
plt.plot(time,amplitude)
plt.grid()
plt.title(' tan graph ')
# Out:
# Text(0.5, 1.0, ' tan graph ')

# %% [markdown]
# ## The parametric equation of circle is x=r*cos(theta) and y=r*sin(theta)

# %%
time=np.arange(0,50,0.01)
r=int(input(' enter the value of rdius ='))
x=r*np.cos(time)
y=r*np.sin(time)
plt.plot(x,y)
# Out:
#  enter the value of rdius =4

# %%
m=int(input(' enter the value of m='))
c=int(input('enter the value of c ='))   
      
x=np.arange(-5,10)
y=m*x+c
plt.plot(x,y)
plt.grid()
plt.axis([-10,10,-10,22])

print()
print('y={}*x+{}'.format(m,c))
# Out:
#  enter the value of m=-7
# enter the value of c =-7
#
# y=-7*x+-7

# %%
straight_line(2,5)
# Out:
# y=2*x+5

# %%
x=np.arange(-5,10)
m=5
c=5
y=m*x+c
plt.plot(x,y)
plt.grid()
plt.axis([-5,10,-10,22])

m=5
c=-5
y=m*x+c
plt.plot(x,y)
plt.grid()
plt.axis([-5,10,-10,22])

m=-5
c=5
y=m*x+c
plt.plot(x,y)
plt.grid()
plt.axis([-5,10,-10,22])

m=-5
c=-5
y=m*x+c
plt.plot(x,y)
plt.grid()
plt.axis([-5,10,-10,22])
plt.grid()
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
x=np.arange(-5,10)
m=5
c=5
y=m*x+c
plt.plot(x,y,label='y=mx+c')
plt.grid()
plt.axis([-5,10,-10,22])

m=5
c=-5
y=m*x+c
plt.plot(x,y,label='y=mx-c')
plt.grid()
plt.axis([-5,10,-10,22])

m=-5
c=5
y=m*x+c
plt.plot(x,y,label='y=-mx+c')
plt.grid()
plt.axis([-5,10,-10,22])

m=-5
c=-5
y=m*x+c
plt.plot(x,y,label='y=mx+c')
plt.grid()
plt.axis([-5,10,-10,22])
plt.grid()
plt.legend()

# %%
x=np.arange(-12,10,0.1)
y=2*x**2-2*x
plt.plot(x,y)
plt.axis([-12,10,-50,120])
plt.grid()

# %%
x=np.arange(-12,10,0.1)
c=5
y=(1/x)*c
plt.plot(x,y)
plt.axis([-12,10,-50,60])
plt.grid()

# %%
x=np.arange(-12,10,0.1)
y=2*x**2-2*x
plt.plot(y,x)
plt.axis([-50,120,-10,10])
plt.grid()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(-5,15,0.1)
k=2
y=(1/x)*k
plt.plot(x,y)

# %%
def root_quadratic():
    import numpy as np
    import cmath
    a=float(input(' Enter the value of a= '))
    b=float(input(' Enter the value of b= '))
    c=float(input(' Enter the value of c= '))
    D=b**2-4*a*c
    
    if D==0:
        x1=-b/(2*a)
        x2=-b/(2*a)
        print(x1)
        print(x2)
    elif D>0:
        x1=(-b+np.sqrt(D))/(2*a)
        x2=(-b-np.sqrt(D))/(2*a)
        print(x1)
        print(x2)
        
    elif D<0:
        x1=(-b+cmath.sqrt(D))/(2*a)
        x2=(-b-cmath.sqrt(D))/(2*a)
        print(x1)
        print(x2)

# %%
root_quadratic()
# Out:
#  Enter the value of a= 1
#  Enter the value of b= 6
#  Enter the value of c= 9
# -3.0
# -3.0
