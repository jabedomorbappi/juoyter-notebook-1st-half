# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc
from zipfile import ZipFile
from io import BytesIO

# Image manipulation.
import PIL.Image
from IPython.display import display



import os

import sys               
import time              
import pickle     
import numpy as np
import pandas as pd
import skimage.measure
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score




import os, sys
from IPython.display import display
from IPython.display import Image as _Imgdis
from PIL import Image
import numpy as np
from time import time
from time import sleep

import cv2
import os
import random
import matplotlib.pylab as plt
from glob import glob
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from scipy import ndimage
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# Using TensorFlow backend.

# %%
from PIL import Image
from numpy import asarray
image=Image.open('jabed1.jpg')
data=asarray(image) #image convert to array

# %%
folder = r'C:\Users\jabed\Desktop\mask and not mask\train\with mask'

onlyfiles = [f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))]

print("Working with {0} images".format(len(onlyfiles)))
# Out:
# Working with 787 images

# %% [markdown]
# for i in range(40, 60):
#     print(onlyfiles[i])
#     display(_Imgdis(filename=folder + "/" + with_mask[i], width=240, height=320))

# %% [markdown]
# from scipy import ndimage
# from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
#
# train_files = []
# y_train = []
# i=0
# for _file in onlyfiles:
#     train_files.append(_file)
#     label_in_file = _file.find("_")
#     y_train.append(int(_file[0:label_in_file]))
#
# print("Files in train_files: %d" % len(train_files))
#
# # Original Dimensions
# image_width = 640
# image_height = 480
# ratio = 4
#
# image_width = int(image_width / ratio)
# image_height = int(image_height / ratio)
#
# channels = 3
# nb_classes = 1
#
# dataset = np.ndarray(shape=(len(train_files), channels, image_height, image_width),
#                      dtype=np.float32)
#
# i = 0
# for _file in train_files:
#     img = load_img(folder + "/" + _file)  # this is a PIL image
#     img.thumbnail((image_width, image_height))
#     # Convert to Numpy Array
#     x = img_to_array(img)
#     x = x.reshape((3, 120, 160))
#     # Normalize
#     x = (x - 128.0) / 128.0
#     dataset[i] = x
#     i += 1
#     if i % 250 == 0:
#         print("%d images to array" % i)
# print("All images to array!")

# %%
PATH = os.path.abspath(os.path.join(r'C:\Users\jabed\Desktop\mask and not mask\train\with mask'))

# %%
train=ImageDataGenerator(rescale=1/255)

# %%
train_dataset=train.flow_from_directory(r'C:\Users\jabed\Desktop\dog and cat classificatin\train',
                                   target_size=(255,255),
                                   batch_size=10,
                                   class_mode='binary'
                                  )
validation_dataset=train.flow_from_directory(r'C:\Users\jabed\Desktop\dog and cat classificatin\validation',
                                   target_size=(255,255),
                                   batch_size=32,
                                   class_mode='binary'
                                  )
# Out:
# Found 8005 images belonging to 2 classes.
# Found 8005 images belonging to 2 classes.

# %%
train_dataset.class
# Out:
#   File "<ipython-input-6-49221788cca4>", line 1
#     train_dataset.class
#                       ^
# SyntaxError: invalid syntax

# %%
import os

path = r'C:\Users\jabed\Desktop\mask and not mask\train'
onlyfiles = os.listdir(path)
len(onlyfiles)

# %% [markdown]
# from skimage import io
#
#
# all_images = []
# for image_path in os.listdir(path):
#
#     img = io.imread(image_path , as_grey=True)
#     img = img.reshape([WIDTH, HEIGHT, 1])
#     all_images.append(img)
# x_train = np.array(all_images)
#
# x_train

# %%
folder =  r'C:\Users\jabed\Desktop\mask and not mask\train\with mask'

onlyfiles = [f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))]

print("Working with {0} images".format(len(onlyfiles)))
print("Image examples: ")

for i in range(40, 42):
    print(onlyfiles[i])
    display(_Imgdis(filename=folder + "/" + onlyfiles[i], width=240, height=320))
# Out:
# Working with 787 images
# Image examples:
# maksssksksss139.png
# maksssksksss140.png

# %%
path=r'C:\Users\jabed\Desktop\dog and cat classificatin\train'
data = []
label = []
Files = ['cats', 'dogs']
label_val = 0

for files in Files:
    cpath = os.path.join(path, files)
    cpath = os.path.join(cpath)
    for img in os.listdir(cpath):
        image_array = cv2.imread(os.path.join(cpath, img), cv2.IMREAD_COLOR)
        data.append(image_array)
        label.append(label_val)
    label_val = 1

# %%
data

# %%
data = np.asarray(data)
label = np.asarray(label)
label
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.1, random_state=42)

# %%
X_train
# Out:
# array([array([[[161,  75, 135],
#         [163,  77, 137],
#         [170,  80, 139],
#         ...,
#         [ 48,  26,  51],
#         [ 47,  25,  50],
#         [ 46,  24,  49]],
#
#        [[161,  75, 135],
#         [165,  77, 137],
#         [171,  81, 140],
#         ...,
#         [ 48,  26,  51],
#         [ 47,  25,  50],
#         [ 46,  24,  49]],
#
#        [[163,  75, 135],
#         [165,  77, 137],
#         [171,  81, 140],
#         ...,
#         [ 51,  26,  54],
#         [ 50,  25,  53],
#         [ 49,  24,  52]],
#
#        ...,
#
#        [[127,  54, 116],
#         [127,  54, 116],
#         [127,  54, 116],
#         ...,
#         [ 39,  24,  51],
#         [ 39,  24,  52],
#         [ 40,  25,  53]],
#
#        [[126,  53, 115],
#         [126,  53, 115],
#         [127,  54, 116],
#         ...,
#         [ 39,  24,  51],
#         [ 40,  25,  53],
#         [ 41,  26,  54]],
#
#        [[124,  51, 113],
#         [125,  52, 114],
# ...

# %%
train_set_x= X_train.reshape(X_train.shape[0],-1).T
# Out:
# (1, 7204)

# %%
7204/2
# Out:
# 3602.0

# %%
np.square(7204)
# Out:
# 51897616

# %%
3602/2
# Out:
# 1801.0
